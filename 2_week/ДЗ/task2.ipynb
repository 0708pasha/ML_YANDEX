# %%
import numpy as np

# %%
M1 = np.array([[2.,5.],[1.,-10.]])
v1 = np.array([1.,3.])

# %%
M1, v1
# Out:
# (array([[  2.,   5.],
#         [  1., -10.]]), array([1., 3.]))

# %%
np.linalg.solve(M1,v1)
# Out:
# array([ 1. , -0.2])
